# %% [markdown]
# Archivo para hacer setup del entorno

# %%
pip install --upgrade pip

# %%
pip install numpy

# %%
pip install sounddevice

# %%
pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 11.1 MB/s  0:00:00 eta 0:00:01
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 10.8 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 9.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 10.9 MB/s  0:00:00 eta 0:00:01
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -e ../libreria
# Out:
# Obtaining file:///home/antipersona/PROYECTOS/AUDIO/libreria
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for audio (pyproject.toml) ... done
#   Created wheel for audio: filename=audio-0.1-0.editable-py3-none-any.whl size=2557 sha256=e93221441f5c35a22bf1b1a2c2fb99b782720c3f56ec616e21e6d08c7561c817
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nsjr0o94/wheels/78/c2/02/0bdc1510dc27d810f2dfcde3af7206c7bfb67abbfc5ebcf6e6
# Successfully built audio
# ...
#   Attempting uninstall: audio
#     Found existing installation: audio 0.1
#     Uninstalling audio-0.1:
#       Successfully uninstalled audio-0.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# check import
import audio
